# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
def load_custom_dataset(dataset_path, img_size=(28, 28)):
    images = []
    labels = []

    
    for folder_name in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder_name)
        if os.path.isdir(folder_path):
            label = int(folder_name)
            
            for image_name in os.listdir(folder_path):
                image_path = os.path.join(folder_path, image_name)
               
                image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                image = cv2.resize(image, img_size)
                
                images.append(image)
                labels.append(label)

  
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# %%
def create_cnn_model(input_shape, num_classes):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (5, 5), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(32, (5, 5), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(32, (5, 5), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(64, (6, 6), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPool2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))
  
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model


dataset_path = "train"

# %%
x, y = load_custom_dataset(dataset_path)
y.shape
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

x = x.astype("float32") / 255.0

# Reshape the data to add a channel dimension
x = x.reshape((x.shape[0], 28, 28, 1))
x.shape

# Convert labels to one-hot encoding
# Out:
# (50683, 28, 28, 1)

# %%
x.shape
# Out:
# (50683, 28, 28, 1)

# %%
# Split the dataset into training and
num_classes = len(np.unique(y))
y = tf.keras.utils.to_categorical(y, num_classes)
num_classes
# Out:
# 156

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


label_binarizer = LabelBinarizer()
label_binarizer.fit(range(num_classes))
# Out:
# LabelBinarizer()

# %%
input_shape = (28, 28, 1)

# %%
model = create_cnn_model(input_shape, num_classes)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\gliff\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 1268/1268 [==============================] - 36s 29ms/step - loss: 1.6589 - accuracy: 0.5107 - val_loss: 3.0074 - val_accuracy: 0.3277
# Epoch 2/50
# 1268/1268 [==============================] - 37s 29ms/step - loss: 1.3202 - accuracy: 0.5989 - val_loss: 0.9782 - val_accuracy: 0.6949
# Epoch 3/50
# 1268/1268 [==============================] - 31s 24ms/step - loss: 1.1583 - accuracy: 0.6423 - val_loss: 2.8084 - val_accuracy: 0.3804
# Epoch 4/50
# 1268/1268 [==============================] - 22s 17ms/step - loss: 1.0587 - accuracy: 0.6701 - val_loss: 1.2501 - val_accuracy: 0.6318
# Epoch 5/50
# 1268/1268 [==============================] - 22s 17ms/step - loss: 0.9928 - accuracy: 0.6878 - val_loss: 0.9263 - val_accuracy: 0.7183
# Epoch 6/50
# 1268/1268 [==============================] - 23s 18ms/step - loss: 0.9325 - accuracy: 0.7044 - val_loss: 1.1767 - val_accuracy: 0.6496
# Epoch 7/50
# 1268/1268 [==============================] - 23s 18ms/step - loss: 0.8787 - accuracy: 0.7239 - val_loss: 0.8325 - val_accuracy: 0.7354
# Epoch 8/50
# 1268/1268 [==============================] - 23s 18ms/step - loss: 0.8461 - accuracy: 0.7307 - val_loss: 0.7580 - val_accuracy: 0.7613
# Epoch 9/50
# 1268/1268 [==============================] - 23s 18ms/step - loss: 0.8083 - accuracy: 0.7404 - val_loss: 0.9126 - val_accuracy: 0.7131
# Epoch 10/50
# 1268/1268 [==============================] - 27s 22ms/step - loss: 0.7826 - accuracy: 0.7484 - val_loss: 1.2201 - val_accuracy: 0.6496
# Epoch 11/50
# 1268/1268 [==============================] - 25s 20ms/step - loss: 0
50
# 1268/1268 [==============================] - 25s 20ms/step - loss: 0.5605 - accuracy: 0.8171 - val_loss: 1.4203 - val_accuracy: 0.6437
# Epoch 33/50
# 1268/1268 [==============================] - 29s 23ms/step - loss: 0.5490 - accuracy: 0.8170 - val_loss: 0.4967 - val_accuracy: 0.8428
# Epoch 34/50
# 1268/1268 [==============================] - 33s 26ms/step - loss: 0.5439 - accuracy: 0.8211 - val_loss: 0.9547 - val_accuracy: 0.7253
# Epoch 35/50
# 1268/1268 [==============================] - 30s 24ms/step - loss: 0.5327 - accuracy: 0.8215 - val_loss: 0.7486 - val_accuracy: 0.7831
# Epoch 36/50
# 1268/1268 [==============================] - 24s 19ms/step - loss: 0.5354 - accuracy: 0.8220 - val_loss: 0.5077 - val_accuracy: 0.8413
# Epoch 37/50
# 1268/1268 [==============================] - 25s 19ms/step - loss: 0.5301 - accuracy: 0.8245 - val_loss: 1.1450 - val_accuracy: 0.6768
# Epoch 38/50
# 1268/1268 [==============================] - 25s 19ms/step - loss: 0.5267 - accuracy: 0.8240 - val_loss: 0.4870 - val_accuracy: 0.8467
# Epoch 39/50
# 1268/1268 [==============================] - 25s 20ms/step - loss: 0.5181 - accuracy: 0.8256 - val_loss: 1.2910 - val_accuracy: 0.6425
# Epoch 40/50
# 1268/1268 [==============================] - 32s 26ms/step - loss: 0.5216 - accuracy: 0.8272 - val_loss: 0.4549 - val_accuracy: 0.8543
# Epoch 41/50
# 1268/1268 [==============================] - 30s 24ms/step - loss: 0.5190 - accuracy: 0.8267 - val_loss: 0.4986 - val_accuracy: 0.8433
# Epoch 42/50
# 1268/1268 [==============================] - 24s 19ms/step - loss: 0.5071 - accuracy: 0.8295 - val_loss: 0.8059 - val_accuracy: 0.7596
# Epoch 43/50
# 1268/1268 [==============================] - 24s 19ms/step - loss: 0.5059 - accuracy: 0.8309 - val_loss: 2.2617 - val_accuracy: 0.4772
# Epoch 44/50
# 1268/1268 [==============================] - 25s 20ms/step - loss: 0.5093 - accuracy: 0.8296 - val_loss: 1.5899 - val_accuracy: 0.5854
# Epoch 45/50
# 1268/1268 [==============================] - 33s 26ms/step - loss: 0.5149 - accuracy: 0.8297 - val_loss: 0.5872 - val_accuracy: 0.8188
# Epoch 46/50
# 1268/1268 [==============================] - 30s 24ms/step - loss: 0.4939 - accuracy: 0.8340 - val_loss: 0.7307 - val_accuracy: 0.7860
# Epoch 47/50
# 1268/1268 [==============================] - 26s 20ms/step - loss: 0.5023 - accuracy: 0.8326 - val_loss: 0.9862 - val_accuracy: 0.7269
# Epoch 48/50
# 1268/1268 [==============================] - 25s 20ms/step - loss: 0.4933 - accuracy: 0.8335 - val_loss: 3.0816 - val_accuracy: 0.4028
# Epoch 49/50
# 1268/1268 [==============================] - 30s 24ms/step - loss: 0.4853 - accuracy: 0.8375 - val_loss: 0.7296 - val_accuracy: 0.7841
# Epoch 50/50
# 1268/1268 [==============================] - 34s 27ms/step - loss: 0.4998 - accuracy: 0.8344 - val_loss: 0.4474 - val_accuracy: 0.8612

# %%
model.save("my_model3")
# Out:
# INFO:tensorflow:Assets written to: my_model3\assets
# INFO:tensorflow:Assets written to: my_model3\assets

# %%
import tensorflow as tf


print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tensorflow as tf
#       4 print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\__init__.py:51
#      49 from tensorflow._api.v2 import autograph
#      50 from tensorflow._api.v2 import bitwise
# ---> 51 from tensorflow._api.v2 import compat
#      52 from tensorflow._api.v2 import config
#      53 from tensorflow._api.v2 import data
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:9
#       6 import sys as _sys
#       8 from tensorflow._api.v2.compat.v1.compat import v1
# ----> 9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#      11 from tensorflow.python.compat.compat import forward_compatible # line: 65
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v2\__init__.py:25
#      22 from tensorflow.python.tools import module_util as _module_util
#      23 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
# ---> 25 from tensorflow._api.v2.compat.v2 import __internal__
#      26 from tensorflow._api.v2.compat.v2 import __operators__
#      27 from tensorflow._api.v2.compat.v2 import audio
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v2\__init__.py:31
#      29 from tensorflow._api.v2.compat.v2 import autograph
#      30 from tensorflow._api.v2.compat.v2 import bitwise
# ---> 31 from tensorflow._api.v2.compat.v2 import compat
#      32 from tensorflow._api.v2.compat.v2 import config
#      33 from tensorflow._api.v2.compat.v2 import data
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v2\compat\__init__.py:9
#       6 import sys as _sys
#       8 from tensorflow._api.v2.compat.v2.compat import v1
# ----> 9 from tensorflow._api.v2.compat.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#      11 from tensorflow.python.compat.compat import forward_compatible # line: 65
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v2\compat\v2\__init__.py:35
#      33 from tensorflow._api.v2.compat.v2 import data
#      34 from tensorflow._api.v2.compat.v2 import debugging
# ---> 35 from tensorflow._api.v2.compat.v2 import distribute
#      36 from tensorflow._api.v2.compat.v2 import dtypes
#      37 from tensorflow._api.v2.compat.v2 import errors
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v2\distribute\__init__.py:10
#       8 from tensorflow._api.v2.compat.v2.distribute import cluster_resolver
#       9 from tensorflow._api.v2.compat.v2.distribute import coordinator
# ---> 10 from tensorflow._api.v2.compat.v2.distribute import experimental
#      11 from tensorflow.python.distribute.collective_all_reduce_strategy import CollectiveAllReduceStrategy as MultiWorkerMirroredStrategy # line: 56
#      12 from tensorflow.python.distribute.cross_device_ops import CrossDeviceOps # line: 251
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\_api\v2\compat\v2\distribute\experimental\__init__.py:18
#      16 from tensorflow.python.distribute.collective_util import _OptionsExported as CommunicationOptions # line: 50
#      17 from tensorflow.python.distribute.distribute_lib import ValueContext # line: 913
# ---> 18 from tensorflow.python.distribute.failure_handling.failure_handling import PreemptionCheckpointHandler # line: 336
#      19 from tensorflow.python.distribute.failure_handling.failure_handling import TerminationConfig # line: 74
#      20 from tensorflow.python.distribute.failure_handling.preemption_watcher import PreemptionWatcher # line: 44
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\failure_handling\failure_handling.py:36
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_worker_util
# ---> 36 from tensorflow.python.distribute.failure_handling import failure_handling_util
#      37 from tensorflow.python.eager import context
#      38 from tensorflow.python.framework import constant_op
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\failure_handling\failure_handling_util.py:19
#      17 import os
#      18 import sys
# ---> 19 import requests
#      21 from six.moves.urllib import request
#      22 from tensorflow.python.eager import context
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\requests\__init__.py:45
#      41 import warnings
#      43 import urllib3
# ---> 45 from .exceptions import RequestsDependencyWarning
#      47 try:
#      48     from charset_normalizer import __version__ as charset_normalizer_version
#
# File c:\Users\gliff\anaconda3\envs\tf\lib\site-packages\requests\exceptions.py:7
#       1 """
#       2 requests.exceptions
#       3 ~~~~~~~~~~~~~~~~~~~
#       4
#       5 This module contains the set of Requests' exceptions.
#       6 """
# ----> 7 from urllib3.exceptions import HTTPError as BaseHTTPError
#       9 from .compat import JSONDecodeError as CompatJSONDecodeError
#      12 class RequestException(IOError):
#
# ModuleNotFoundError: No module named 'urllib3.exceptions'

# %%
pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\gliff\anaconda3\envs\tf\lib\site-packages (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
a='ெ'
b='க'
d= 'ா' 
c=a+d

# %%
c
# Out:
# 'ொ'

# %%
t=[]
if predicted==a:
    t.append(a)
